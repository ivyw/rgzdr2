# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import json
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np

import rgz.constants
from rgz.plot import subject as plot_subject
from rgz import subjects
from rgz import testutils

# %%
base_path = Path('/home/matthew/native-repos/rgzdr2/data/')
processed_subjects_path = base_path / 'radio_subjects_subset_processed.json'

# %%
cache = Path('/home/matthew/native-repos/rgzdr2/data/cache')

# %%
with open(processed_subjects_path) as f:
    subjects_json = json.load(f)

# %%
subject = subjects.Subject.from_json(subjects_json[0])

# %%
subject
# Out:
# Subject(id='52af7eb58c51f405a600001b', zid='ARG0002w6r', coords=[151.87758333333332, 12.038472222222222], bboxes={(26.4, 50.8, 15.5, 29.1): ['FIRST_J100734.7+120304', 'FIRST_J100734.9+120246', 'FIRST_J100734.9+120257'], (71.7, 71.2, 58.0, 58.4): ['FIRST_J100730.6+120218']})

# %%
for i in range(100):
    ax = plot_subject.plot_single_subject(subjects.Subject.from_json(subjects_json[i]), cache, ax=None)
    plt.show()
    plt.close(ax.get_figure())
    break
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---SIN' 'DEC--SIN'
# CUNIT : 'deg' 'deg'
# CRVAL : 151.416293 12.115556
# CRPIX : 1248.0 267.0
# NAXIS : 132  132
